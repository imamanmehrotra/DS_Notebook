# %% [markdown]
# # DS Tut 1 - 20 Nov 2021

# %%
# !pip install pandas

# %%
conda list numpy
# Out:
# # packages in environment at /Users/amanmehrotra/opt/anaconda3:
# #
# # Name                    Version                   Build  Channel
# numpy                     1.19.5                   pypi_0    pypi
# numpydoc                  1.1.0              pyhd3eb1b0_1
#
# Note: you may need to restart the kernel to use updated packages.

# %%
#csv file reading

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
url='https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
df=pd.read_csv(url)

# %%
#dataframe
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #### Dataset Description:

# %% [markdown]
# ![datasetinfo.png](attachment:datasetinfo.png)

# %% [markdown]
# ![data-science-in-marketing-post-venn-diagram.jpeg](attachment:data-science-in-marketing-post-venn-diagram.jpeg)

# %% [markdown]
# ## Types of ML Algorithms

# %% [markdown]
#  - Supervised ML Algos
#  - Unsupervised ML Algos
#  - Associative ML Algos
#  - Clustering ML Algos

# %% [markdown]
# Supervised ML Algos:
#
# - labelled data

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
type(df['Fare'])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df1=df[['Pclass',  'Sex', 'Age', 'SibSp',
       'Parch',  'Fare', 'Cabin', 'Embarked','Survived']]

# %%
df1
# Out:
#      Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked  Survived
# 0         3    male  22.0      1      0   7.2500   NaN        S         0
# 1         1  female  38.0      1      0  71.2833   C85        C         1
# 2         3  female  26.0      0      0   7.9250   NaN        S         1
# 3         1  female  35.0      1      0  53.1000  C123        S         1
# 4         3    male  35.0      0      0   8.0500   NaN        S         0
# ..      ...     ...   ...    ...    ...      ...   ...      ...       ...
# 886       2    male  27.0      0      0  13.0000   NaN        S         0
# 887       1  female  19.0      0      0  30.0000   B42        S         1
# 888       3  female   NaN      1      2  23.4500   NaN        S         0
# 889       1    male  26.0      0      0  30.0000  C148        C         1
# 890       3    male  32.0      0      0   7.7500   NaN        Q         0
#
# [891 rows x 9 columns]

# %%
# Shape of Dataset
df1.shape
# Out:
# (891, 9)

# %%
# for first few rows

df1.head(15)
# Out:
#     Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked  Survived
# 0        3    male  22.0      1      0   7.2500   NaN        S         0
# 1        1  female  38.0      1      0  71.2833   C85        C         1
# 2        3  female  26.0      0      0   7.9250   NaN        S         1
# 3        1  female  35.0      1      0  53.1000  C123        S         1
# 4        3    male  35.0      0      0   8.0500   NaN        S         0
# 5        3    male   NaN      0      0   8.4583   NaN        Q         0
# 6        1    male  54.0      0      0  51.8625   E46        S         0
# 7        3    male   2.0      3      1  21.0750   NaN        S         0
# 8        3  female  27.0      0      2  11.1333   NaN        S         1
# 9        2  female  14.0      1      0  30.0708   NaN        C         1
# 10       3  female   4.0      1      1  16.7000    G6        S         1
# 11       1  female  58.0      0      0  26.5500  C103        S         1
# ...

# %%
#for last few rows

df1.tail(15)
# Out:
#      Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked  Survived
# 876       3    male  20.0      0      0   9.8458   NaN        S         0
# 877       3    male  19.0      0      0   7.8958   NaN        S         0
# 878       3    male   NaN      0      0   7.8958   NaN        S         0
# 879       1  female  56.0      0      1  83.1583   C50        C         1
# 880       2  female  25.0      0      1  26.0000   NaN        S         1
# 881       3    male  33.0      0      0   7.8958   NaN        S         0
# 882       3  female  22.0      0      0  10.5167   NaN        S         0
# 883       2    male  28.0      0      0  10.5000   NaN        S         0
# 884       3    male  25.0      0      0   7.0500   NaN        S         0
# 885       3  female  39.0      0      5  29.1250   NaN        Q         0
# 886       2    male  27.0      0      0  13.0000   NaN        S         0
# 887       1  female  19.0      0      0  30.0000   B42        S         1
# ...

# %% [markdown]
# ## DS Tut 2: 21/11/2021

# %%
#for picking the rows randomly

df1.sample(15)
plt.figure(figsize=[15,20]);
plt.hist(df1['Survived']);

# %%
#For seeing the Statistics of Dataframe

df1.describe()
# Out:
#            Pclass         Age       SibSp       Parch        Fare    Survived
# count  891.000000  714.000000  891.000000  891.000000  891.000000  891.000000
# mean     2.308642   29.699118    0.523008    0.381594   32.204208    0.383838
# std      0.836071   14.526497    1.102743    0.806057   49.693429    0.486592
# min      1.000000    0.420000    0.000000    0.000000    0.000000    0.000000
# 25%      2.000000   20.125000    0.000000    0.000000    7.910400    0.000000
# 50%      3.000000   28.000000    0.000000    0.000000   14.454200    0.000000
# 75%      3.000000   38.000000    1.000000    0.000000   31.000000    1.000000
# max      3.000000   80.000000    8.000000    6.000000  512.329200    1.000000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    891 non-null    int64
#  1   Sex       891 non-null    object
#  2   Age       714 non-null    float64
#  3   SibSp     891 non-null    int64
#  4   Parch     891 non-null    int64
#  5   Fare      891 non-null    float64
#  6   Cabin     204 non-null    object
#  7   Embarked  889 non-null    object
#  8   Survived  891 non-null    int64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
df1.isnull().any()
# Out:
# Pclass      False
# Sex         False
# Age          True
# SibSp       False
# Parch       False
# Fare        False
# Cabin        True
# Embarked     True
# Survived    False
# dtype: bool

# %%
df1.nunique()
# Out:
# Pclass        3
# Sex           2
# Age          88
# SibSp         7
# Parch         7
# Fare        248
# Cabin       147
# Embarked      3
# Survived      2
# dtype: int64

# %% [markdown]
# 2 Types of values are present in a dataset always:
#  - Categorical Variables - on the basis of which you can divide/classify your dataset into different categories
#  - Continuous Variables (Numerical Data) - used for performing metric level calculations

# %% [markdown]
# ### What are steps to set up a ML Data Pipeine?
#
#  - ETL (Extract, Trnasformation, Load) - Descriptive Analytics (Informatica, Alteryx)
#  - ML (Machine Learning) - Predictive Analytics ( Knime, Matlab, Python, R, Shiny)

# %% [markdown]
#  - Raw data
#  - Clean the data
#  - Process the data
#  - Model the data
#  - Get insights from data using predictions
#  - Report the data

# %% [markdown]
# Artificial Intelligence, Data Science, Machine Learning, Deep Learning, Neural Networks, Data Engineering

# %% [markdown]
# # EDA - Exploratory Data Analysis

# %%
df1
# Out:
#      Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked  Survived
# 0         3    male  22.0      1      0   7.2500   NaN        S         0
# 1         1  female  38.0      1      0  71.2833   C85        C         1
# 2         3  female  26.0      0      0   7.9250   NaN        S         1
# 3         1  female  35.0      1      0  53.1000  C123        S         1
# 4         3    male  35.0      0      0   8.0500   NaN        S         0
# ..      ...     ...   ...    ...    ...      ...   ...      ...       ...
# 886       2    male  27.0      0      0  13.0000   NaN        S         0
# 887       1  female  19.0      0      0  30.0000   B42        S         1
# 888       3  female   NaN      1      2  23.4500   NaN        S         0
# 889       1    male  26.0      0      0  30.0000  C148        C         1
# 890       3    male  32.0      0      0   7.7500   NaN        Q         0
#
# [891 rows x 9 columns]

# %%
df1.isnull().sum()
# Out:
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Cabin       687
# Embarked      2
# Survived      0
# dtype: int64

# %% [markdown]
# Imputation - means to fill in the data wherever we have null values in any column

# %% [markdown]
# Co-relation: It means the relationship between features

# %%
plt.figure(figsize=[15,10])
sns.heatmap(df1.corr(), annot=True);
#df1.corr()

# %% [markdown]
#  - Negative co-relation: Inversely proportional Relationship
#  - Positive co-relation: Directly Proportional Relationship

# %% [markdown]
# Date: 22/11/2021
# ## Feature Engneering
#
#  - To make the dataset more undestandable to our Machine Learning Algorithms
#  - To scale up or down each feature so as to bring the dataset on common scale (Also known as Transformation)

# %%
df1
# Out:
#      Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked  Survived
# 0         3    male  22.0      1      0   7.2500   NaN        S         0
# 1         1  female  38.0      1      0  71.2833   C85        C         1
# 2         3  female  26.0      0      0   7.9250   NaN        S         1
# 3         1  female  35.0      1      0  53.1000  C123        S         1
# 4         3    male  35.0      0      0   8.0500   NaN        S         0
# ..      ...     ...   ...    ...    ...      ...   ...      ...       ...
# 886       2    male  27.0      0      0  13.0000   NaN        S         0
# 887       1  female  19.0      0      0  30.0000   B42        S         1
# 888       3  female   NaN      1      2  23.4500   NaN        S         0
# 889       1    male  26.0      0      0  30.0000  C148        C         1
# 890       3    male  32.0      0      0   7.7500   NaN        Q         0
#
# [891 rows x 9 columns]

# %%
df1['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
#Pandas

pd.get_dummies(df1['Embarked'], drop_first=True)
# Out:
#      Q  S
# 0    0  1
# 1    0  0
# 2    0  1
# 3    0  1
# 4    0  1
# ..  .. ..
# 886  0  1
# 887  0  1
# 888  0  1
# 889  0  0
# 890  1  0
#
# [891 rows x 2 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
l=pd.DataFrame(le.fit_transform(df1['Embarked']), columns=['Embarked'])
l
# Out:
#      Embarked
# 0           2
# 1           0
# 2           2
# 3           2
# 4           2
# ..        ...
# 886         2
# 887         2
# 888         2
# 889         0
# 890         1
#
# [891 rows x 1 columns]

# %%
#le.fit_transform(df1['Embarked']) -->for reading the transformed data

# %%
df1.drop('Embarked',axis=1,inplace=True)   #Columns in pandas are rep by 1 and row by 0
# Out:
# /Users/amanmehrotra/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df1
# Out:
#      Pclass     Sex   Age  SibSp  Parch     Fare Cabin  Survived
# 0         3    male  22.0      1      0   7.2500   NaN         0
# 1         1  female  38.0      1      0  71.2833   C85         1
# 2         3  female  26.0      0      0   7.9250   NaN         1
# 3         1  female  35.0      1      0  53.1000  C123         1
# 4         3    male  35.0      0      0   8.0500   NaN         0
# ..      ...     ...   ...    ...    ...      ...   ...       ...
# 886       2    male  27.0      0      0  13.0000   NaN         0
# 887       1  female  19.0      0      0  30.0000   B42         1
# 888       3  female   NaN      1      2  23.4500   NaN         0
# 889       1    male  26.0      0      0  30.0000  C148         1
# 890       3    male  32.0      0      0   7.7500   NaN         0
#
# [891 rows x 8 columns]

# %%
df1=pd.concat((df1,l),axis=1)

# %%
df1.columns
# Out:
# Index(['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Cabin', 'Survived',
#        'Embarked'],
#       dtype='object')

# %%
df1=df1[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Cabin',
       'Embarked', 'Survived']]
df1
# Out:
#      Pclass     Sex   Age  SibSp  Parch     Fare Cabin  Embarked  Survived
# 0         3    male  22.0      1      0   7.2500   NaN         2         0
# 1         1  female  38.0      1      0  71.2833   C85         0         1
# 2         3  female  26.0      0      0   7.9250   NaN         2         1
# 3         1  female  35.0      1      0  53.1000  C123         2         1
# 4         3    male  35.0      0      0   8.0500   NaN         2         0
# ..      ...     ...   ...    ...    ...      ...   ...       ...       ...
# 886       2    male  27.0      0      0  13.0000   NaN         2         0
# 887       1  female  19.0      0      0  30.0000   B42         2         1
# 888       3  female   NaN      1      2  23.4500   NaN         2         0
# 889       1    male  26.0      0      0  30.0000  C148         0         1
# 890       3    male  32.0      0      0   7.7500   NaN         1         0
#
# [891 rows x 9 columns]

# %% [markdown]
# #### Date: 23/11/2021
#
# Features of Pandas

# %%
df1
# Out:
#      Pclass     Sex   Age  SibSp  Parch     Fare Cabin  Embarked  Survived
# 0         3    male  22.0      1      0   7.2500   NaN         2         0
# 1         1  female  38.0      1      0  71.2833   C85         0         1
# 2         3  female  26.0      0      0   7.9250   NaN         2         1
# 3         1  female  35.0      1      0  53.1000  C123         2         1
# 4         3    male  35.0      0      0   8.0500   NaN         2         0
# ..      ...     ...   ...    ...    ...      ...   ...       ...       ...
# 886       2    male  27.0      0      0  13.0000   NaN         2         0
# 887       1  female  19.0      0      0  30.0000   B42         2         1
# 888       3  female   NaN      1      2  23.4500   NaN         2         0
# 889       1    male  26.0      0      0  30.0000  C148         0         1
# 890       3    male  32.0      0      0   7.7500   NaN         1         0
#
# [891 rows x 9 columns]

# %%
df1.isnull().sum()
# Out:
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Cabin       687
# Embarked      0
# Survived      0
# dtype: int64

# %%
#Observing the rows with null values on the basis of certain columns

df1[df1["Age"].isna()]
# Out:
#      Pclass     Sex  Age  SibSp  Parch     Fare Cabin  Embarked  Survived
# 5         3    male  NaN      0      0   8.4583   NaN         1         0
# 17        2    male  NaN      0      0  13.0000   NaN         2         1
# 19        3  female  NaN      0      0   7.2250   NaN         0         1
# 26        3    male  NaN      0      0   7.2250   NaN         0         0
# 28        3  female  NaN      0      0   7.8792   NaN         1         1
# ..      ...     ...  ...    ...    ...      ...   ...       ...       ...
# 859       3    male  NaN      0      0   7.2292   NaN         0         0
# 863       3  female  NaN      8      2  69.5500   NaN         2         0
# 868       3    male  NaN      0      0   9.5000   NaN         2         0
# 878       3    male  NaN      0      0   7.8958   NaN         2         0
# 888       3  female  NaN      1      2  23.4500   NaN         2         0
#
# [177 rows x 9 columns]

# %%
df1[~df1["Age"].isna()]
# Out:
#      Pclass     Sex   Age  SibSp  Parch     Fare Cabin  Embarked  Survived
# 0         3    male  22.0      1      0   7.2500   NaN         2         0
# 1         1  female  38.0      1      0  71.2833   C85         0         1
# 2         3  female  26.0      0      0   7.9250   NaN         2         1
# 3         1  female  35.0      1      0  53.1000  C123         2         1
# 4         3    male  35.0      0      0   8.0500   NaN         2         0
# ..      ...     ...   ...    ...    ...      ...   ...       ...       ...
# 885       3  female  39.0      0      5  29.1250   NaN         1         0
# 886       2    male  27.0      0      0  13.0000   NaN         2         0
# 887       1  female  19.0      0      0  30.0000   B42         2         1
# 889       1    male  26.0      0      0  30.0000  C148         0         1
# 890       3    male  32.0      0      0   7.7500   NaN         1         0
#
# [714 rows x 9 columns]

# %%
url1='https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
df_new=pd.read_csv(url1, header=None)

# %%
df_new
# Out:
#               0         1       2   \
# 0    PassengerId  Survived  Pclass
# 1              1         0       3
# 2              2         1       1
# 3              3         1       3
# 4              4         1       1
# ..           ...       ...     ...
# 887          887         0       2
# 888          888         1       1
# 889          889         0       3
# 890          890         1       1
# 891          891         0       3
#
#                                                     3       4    5      6   \
# 0                                                 Name     Sex  Age  SibSp
# 1                              Braund, Mr. Owen Harris    male   22      1
# 2    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 3                               Heikkinen, Miss. Laina  female   26      0
# 4         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# ..                                                 ...     ...  ...    ...
# ...

# %%
df_new1=pd.read_csv(url1, usecols=['Survived','Pclass','Sex'])
df_new1
# Out:
#      Survived  Pclass     Sex
# 0           0       3    male
# 1           1       1  female
# 2           1       3  female
# 3           1       1  female
# 4           0       3    male
# ..        ...     ...     ...
# 886         0       2    male
# 887         1       1  female
# 888         0       3  female
# 889         1       1    male
# 890         0       3    male
#
# [891 rows x 3 columns]

# %%
url1='https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
df_2=pd.read_csv(url1)
df_2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## Introduction of LOC and ILOC: (V.Imp for interview)
#
#  - LOC: Location based extraction (old version)
#  - ILOC: Index Location based extraction (latest version)

# %%
df_2.iloc[15:43,]
# Out:
#     PassengerId  Survived  Pclass  \
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# 26           27         0       3
# 27           28         0       1
# 28           29         1       3
# 29           30         0       3
# 30           31         0       1
# 31           32         1       1
# 32           33         1       3
# 33           34         0       2
# 34           35         0       1
# 35           36         0       1
# 36           37         1       3
# 37           38         0       3
# 38           39         0       3
# 39           40         1       3
# 40           41         0       3
# ...

# %%
df_2.iloc[15:43,3:7]
# Out:
#                                                  Name     Sex   Age  SibSp
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                               Rice, Master. Eugene    male   2.0      4
# 17                       Williams, Mr. Charles Eugene    male   NaN      0
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                            Masselmani, Mrs. Fatima  female   NaN      0
# 20                               Fynney, Mr. Joseph J    male  35.0      0
# 21                              Beesley, Mr. Lawrence    male  34.0      0
# 22                        McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                       Sloper, Mr. William Thompson    male  28.0      0
# 24                      Palsson, Miss. Torborg Danira  female   8.0      3
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# ...

# %%
df_2.set_index(keys='PassengerId')
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...
